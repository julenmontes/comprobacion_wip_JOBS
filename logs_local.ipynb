# %%
import pandas as pd
from datetime import datetime, timedelta
# clases_regla = pd.read_csv('clases_regla.csv', dtype={'rule':str})[['rule','type_rules']]
# clases_regla_dict = clases_regla.set_index('rule').type_rules.to_dict()
clases_regla_dict = {
    '3.1': 'com.datio.hammurabi.rules.validity.NotNullValidationRule',
    '3.2': 'com.datio.hammurabi.rules.validity.FormatValidationRule',
    '3.3': 'com.datio.hammurabi.rules.validity.DynamicForbiddenValuesRule',
    '3.4': 'com.datio.hammurabi.rules.validity.DateRangeRule',
    '3.5s': 'com.datio.hammurabi.rules.validity.StaticCatalogRule',
    '3.5d': 'com.datio.hammurabi.rules.validity.DynamicCatalogRule',
    '4.2': 'com.datio.hammurabi.rules.consistence.DuplicateRule',
    '4.3': 'com.datio.hammurabi.rules.consistence.ValueConciliationRule',
    '5.2': 'com.datio.hammurabi.rules.integrity.ValueComparisonRule',
    '5.3': 'com.datio.hammurabi.rules.integrity.SameValueComparisonRule',
    '5.4': 'com.datio.hammurabi.rules.integrity.ConditionalExpressionObjectByRowRule',
    '5.5': 'com.datio.hammurabi.rules.integrity.ConditionalExpressionObjectsByRowRule',
    '5.6': 'com.datio.hammurabi.rules.integrity.ConcatRuleByColumn',
    '6.1': 'com.datio.hammurabi.rules.accuracy.GatheringByRowRule',
    '6.1': 'com.datio.hammurabi.rules.accuracy.StaticRatingVariationRule',
    '6.11': 'com.datio.hammurabi.rules.accuracy.HerfindahlRule',
    '6.2': 'com.datio.hammurabi.rules.accuracy.ValueSensitivityThresholdRule',
    '6.4': 'com.datio.hammurabi.rules.accuracy.ValueAbsoluteVariationRule',
    '6.9': 'com.datio.hammurabi.rules.accuracy.VolumetricTrendRule'
}

# %%
n_records = 4
date = (datetime.today() - timedelta(days=1, hours=1, minutes=13)).strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]

tabla = "t_kcpg_expense_group_participant" # <----------------------------------------------------------------------------------------- RELLENAR

dict_reglas = [
    {
        "tipo":"3.1",
        "campo":"g_entity_id",
        "critical": "true" #true #false
    },
        {
        "tipo":"3.1",
        "campo":"gf_expenses_group_member_id",
        "critical": "true" #true #false
    },
        {
        "tipo":"3.1",
        "campo":"gf_expenses_group_id",
        "critical": "true" #true #false
    },
    {
        "tipo":"3.2",
        "campo":"g_entity_id",
        "critical": "true" #true #false
    },
        {
        "tipo":"3.2",
        "campo":"gf_expenses_group_member_id",
        "critical": "true" #true #false
    },
        {
        "tipo":"3.2",
        "campo":"gf_expenses_group_id",
        "critical": "true" #true #false
    },
    #     {
    #     "tipo":"4.3",
    #     "campo":"g_entity_id",
    #     "critical": "true" #true #false
    # },
    # {
    #     "tipo":"6.9",
    #     "campo":"",
    #     "critical": "true" #true #false
    # },
    # {
    #     "tipo":"4.2",
    #     "campo":"",
    #     "critical": "true" #true #false
    # },

    # {
    #     "tipo":"5.6",
    #     "campo":"g_entity_id",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.4",
    #     "campo":"gf_flow_version_number",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.4",
    #     "campo":"gf_genesys_metric_val_number",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.4",
    #     "campo":"gf_max_latency_val_number",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.4",
    #     "campo":"gf_min_mos_value_number",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.4",
    #     "campo":"gf_prt_min_r_factor_number",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.4",
    #     "campo":"gf_q850responsecodes_ars",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.4",
    #     "campo":"gf_received_packt_convr_number",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.4",
    #     "campo":"gf_sec_bf_callback_gen_number",
    #     "critical": "false" #true #false
    # },
    {
        "tipo":"3.5d",
        "campo":"g_expenses_group_mbr_type",
        "critical": "false" #true #false
    },
    {
        "tipo":"3.5d",
        "campo":"g_exp_gp_mbr_t_bal_am_st_type",
        "critical": "false" #true #false
    },
    # {
    #     "tipo":"3.5d",
    #     "campo":"g_role_int_int_type",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.5s",
    #     "campo":"gf_sent_act_ind_type",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.5s",
    #     "campo":"gf_convr_atch_files_ind_type",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.5s",
    #     "campo":"gf_convr_logical_del_ind_type",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.5s",
    #     "campo":"gf_convr_cust_draft_ind_type",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.5s",
    #     "campo":"gf_convr_certified_ind_type",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.5s",
    #     "campo":"gf_contact_center_ind_type",
    #     "critical": "false" #true #false
    # },
    # {
    #     "tipo":"3.5s",
    #     "campo":"gf_conv_ai_auto_rsln_ind_type",
    #     "critical": "false" #true #false
    # },
        {
        "tipo":"4.2",
        "campo":"",
        "critical": "true" #true #false
    },
]

# %%
print("""
########                          DATA QUALITY RESULTS                          ########
########################################################################################
--> DATASET
----> ObjectPath: Some(/data/master/{ua}/data/{t})
----> PhysicalObject: {t}
----> UUAA: kcpg
----> Subset: Some(gf_cutoff_date='1997-01-01')
----> FrequencyRuleExecution: None
----> Dataset size: {n} rows
----> Data date: 1997-01-01
----> Execution date: {d}
--> RESULTS""".format(t=tabla, n=n_records, ua=tabla[:6][2:6], d=date))

for r in dict_reglas:
    print('----> Rule: {rule} ({t})'.format(rule=r['tipo'][:3], t = clases_regla_dict[r['tipo']]))
    print('----> Subset: None')
    print('----> Physical field: {0}'.format(r['campo']))
    print('----> Is Critical: {0}'.format(r['critical']))
    print('----> DrillDown: Some()>Some()')
    print('----> MinimumThreshold: None')
    print('----> TargetThreshold: None')
    print('----> Passed records: {0}'.format(n_records))
    print('----> Total records affected: {0}'.format(n_records))
    print('----> Compliance percentage: 100.0')
    print('----> Acceptance Min: None')
    print('----> Final status: Passed')
    print('----> -------------------------------')

print("""########################################################################################
########                             END OF RESULTS                             ########
########################################################################################

Process finished with exit code 0""")
# Out:
# ########                          DATA QUALITY RESULTS                          ########
# ########################################################################################
# --> DATASET
# ----> ObjectPath: Some(/data/master/kcpg/data/t_kcpg_expense_group_participant)
# ----> PhysicalObject: t_kcpg_expense_group_participant
# ----> UUAA: kcpg
# ----> Subset: Some(gf_cutoff_date='1997-01-01')
# ----> FrequencyRuleExecution: None
# ----> Dataset size: 4 rows
# ----> Data date: 1997-01-01
# ----> Execution date: 2025-08-20 13:11:20.873
# --> RESULTS
# ----> Rule: 3.1 (com.datio.hammurabi.rules.validity.NotNullValidationRule)
# ----> Subset: None
# ----> Physical field: g_entity_id
# ----> Is Critical: true
# ----> DrillDown: Some()>Some()
# ----> MinimumThreshold: None
# ----> TargetThreshold: None
# ----> Passed records: 4
# ----> Total records affected: 4
# ----> Compliance percentage: 100.0
# ----> Acceptance Min: None
# ----> Final status: Passed
# ...
