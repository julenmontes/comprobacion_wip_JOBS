# %% [markdown]
# > # ATENCIÓN:
# > ## 1. Para lanzar el script el WIP debe estar consolidado o **todas las reglas deben tener versión**
# > ## 2. Las reglas deben estar marcadas como **"DELIVERED"**
# > Las otras reglas/confs se ignorarán
# > ## 3. Se deben rellenar las UUAAs a desplegar/modificar
# > Sino, se cogerán todas las UUAAs presentes en el WIP
# > ## 4. Rellenar, si la hay, version_personalizada.
# >Sino, se cogerá la última versión en el WIP para cada UUAA. De cara al TAG de la URL del job en la documentación
# >- Ejemplo:
# > https://bitbucket.gobaldevtools.bbva.com/bitbucket/projects/GL_B0HN_APP-ID-23103_DSG/repos/glgldh360gloqlt/browse/hammurabi/jobs/b0hn-gl-hmm-qlt-sustgroupsfdbkmmrule-03.json?at=refs%2Ftags%2Fv14.0.3
# > - En este caso, versión de subida:
# > 14.0.3

# %%
# !pip install --trusted-host=pypi.org --trusted-host=files.pythonhosted.org --user -U numpy 
# !pip install --trusted-host=pypi.org --trusted-host=files.pythonhosted.org --user "C:\Users\O005820\Downloads\numpy-2.2.4.tar.gz"
# !pip uninstall numpy
# !dir C:\Users\O005820\Downloads

# %%
import os
import shutil
import pandas as pd
import numpy as np
import json
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# IMPORTANTE: Indicamos UUAAs a modificar

# %%
UUAAs = [] #se cogerán todas las UUAAs del WIP

#selección de UUAAs
UUAAs = [
'KSZG',
'P6R1',
'G5M3',
]

version_personalizada = "" #RELLENAR EN ACTUALIZACIONES MASIVAS: versión de subida de jobs (si no es para todos la misma, dejarlo vacío y cogerá la ultima versión del wip para cada UUAA)

if not UUAAs:
    print('UUAAs no declaradas (UUAAs = [])\n-> Se actualizarán todas las UUAAs presentes en el WIP con reglas DELIVERED,\nversión',version_personalizada)
else:
    UUAAs = [i.lower() for i in UUAAs]
    print('UUAAs declaradas\n-> Se actualizarán las siguientes UUAAs')
    print(UUAAs)
# Out:
# UUAAs declaradas
# -> Se actualizarán las siguientes UUAAs
# ['kszg', 'p6r1', 'g5m3']

# %%
dict_tablas = {
    # 't_tdi3_cust_promo_adhesion_dp':'a',
    # 't_re4m_virtual_assistant_message':'b'
}

# %% [markdown]
# Confs

# %%
extralib_job_eur = {
    "jobName": "test",
    "description": "test",
    "size": "XS",
    "runtime": "hammurabi-lts",
    "streaming": False,
    "params": {
        "metaConfig": "gl:re4m:glgldh360gloqlt:RE4M_physical-interaction_MRField:14.0.7",
        "extraLibs": "s3://ada-eu-south-2-core-live-artifacts/dataproc/migration-artifacts/artifactory/gl-datio-spark-libs-maven-local/com/bbva/projectsdatio/c360hammcustom/1.3.4/c360hammcustom-1.3.4-jar-with-dependencies.jar" 
    },
    "env": {
        "XD_ENABLED":"true"
    },
    "tags": [ #https://docs.google.com/document/d/1nTowUue9ahe3-T69lvLM_vASvvfrueJz9qek2cYwwrk/edit?tab=t.0
        "sdm",
        "360",
        "cs",
        "gl",
        "qlt",
        "global",
        "master",
        "SDATOOL-49915"
    ],
    "kind": "processing",
    "concurrency": 10
}

# %%
other_job_eur = {
    "jobName": "test",
    "description": "test",
    "size": "XS",
    "runtime": "hammurabi-lts",
    "streaming": False,
    "params": {
        "metaConfig": "gl:re4m:glgldh360gloqlt:RE4M_physical-interaction_MRField:14.0.7",
    },
    "env": {
        "XD_ENABLED":"true"
    },
    "tags": [
        "sdm",
        "360",
        "cs",
        "gl",
        "qlt",
        "global",
        "master",
        "SDATOOL-49915"
    ],
    "kind": "processing",
    "concurrency": 10
}

# %%
extralib_job_ame = {
        "_id": "test",
        "description": "test",
        "size": "XS",
        "runtime": "hammurabi-lts",
        "streaming": False,
        "params": {
                "configUrl": "https://artifactory-gdt.central-01.nextgen.igrupobbva/artifactory/gl-datio-spark-libs-maven-dev-local/com/datiobd/c360-hammurabi/99.9.9-PR-351-SNAPSHOT/entregable_hammurabi/L9CT/L9CT_grp-clnt-cmpny-crbn-data_CIB_MRField.conf",
                "repoSecurity": "artifactory",
                "sparkHistoryEnabled": "false",
                "extraLibs": "https://artifactory-gdt.central-01.nextgen.igrupobbva/artifactory/gl-datio-spark-libs-maven-local/com/bbva/gdh/hammurabi-maxminfilter/1.2.0/hammurabi-maxminfilter-1.2.0-jar-with-dependencies.jar"
        },
        "env": {
                "XD_ENABLED":"true"
        },
        "tags": [
        "sdm",
        "360",
        "cs",
        "gl",
        "qlt",
        "global",
        "master",
        "SDATOOL-49915"
        ],
        "kind": "processing"
}

# %%
other_job_ame = {
    "_id": "test",
    "description": "test",
    "size": "XS",
    "runtime": "hammurabi-lts",
    "streaming": False,
    "params": {
        "configUrl": "https://artifactory-gdt.central-01.nextgen.igrupobbva/artifactory/gl-datio-spark-libs-maven-dev-local/com/datiobd/c360-hammurabi/12.1.0-PR-321-SNAPSHOT/entregable_hammurabi/KCDG/KCDG_graph-edges_KCDG_graph-nodes_MMRule.conf",
        "repoSecurity": "artifactory",
        "sparkHistoryEnabled": "false"
    },
    "env": {
        "XD_ENABLED":"true"
    },
    "tags": [
        "sdm",
        "360",
        "cs",
        "gl",
        "qlt",
        "global",
        "master",
        "SDATOOL-49915"
    ],
    "kind": "processing"
}

# %% [markdown]
# WIP confs

# %%
cols = ['STATUS IMPLANTATION','TABLE (en C360)','Secondary Table (4.3-5.2-6.4)','Conf (MRField, ORField, OCField,...)', 'Conf name', 'version  FINISHED','Url conf\nv13.0.4 (new)','Url Extralibs','IMPLANTATION TYPE']
wip = pd.read_csv('wip_final.csv', header=1)[cols].dropna(subset='version  FINISHED')

wip = wip[wip['STATUS IMPLANTATION']=="DELIVERED"]

wip['version_simple'] = wip['version  FINISHED'].str.replace("5.0.15","5.0.1").str.replace(".","").astype(int)
wip['unique_id'] = wip['TABLE (en C360)'].str[6:].str.replace('_','').str[:19] + wip['Conf name'].str.lower().str.split('_').str[-1].str.split('.').str[0]
wip['NombreJob'] = wip['Conf name'].str[:4].str.lower() + '-' + 'gl' + '-' + 'hmm' + '-' + 'qlt' + '-' + wip['unique_id'] + '-'
wip.sort_values(['version_simple','Url Extralibs','version_simple'], inplace=True, ascending=False)
wip.drop_duplicates(subset=['Conf name','version_simple'], inplace=True)
wip.reset_index(drop=True,inplace=True)
print(wip.columns)
print()
print(wip.isnull().sum())
wip.columns = ['satus_implantation','table','secundary_table','conf_type','conf','version','ConfigURL','Extralibs','implantation','version_simple','unique_id','NombreJob']
wip['len_unique_id'] = wip.unique_id.str.len()
wip.tail(2)
# Out:
# Index(['STATUS IMPLANTATION', 'TABLE (en C360)',
#        'Secondary Table (4.3-5.2-6.4)', 'Conf (MRField, ORField, OCField,...)',
#        'Conf name', 'version  FINISHED', 'Url conf\nv13.0.4 (new)',
#        'Url Extralibs', 'IMPLANTATION TYPE', 'version_simple', 'unique_id',
#        'NombreJob'],
#       dtype='object')
#
# STATUS IMPLANTATION                        0
# TABLE (en C360)                            0
# Secondary Table (4.3-5.2-6.4)            712
# Conf (MRField, ORField, OCField,...)       0
# Conf name                                  0
# version  FINISHED                          0
# Url conf\nv13.0.4 (new)                    0
# Url Extralibs                           1016
# IMPLANTATION TYPE                          0
# version_simple                             0
# unique_id                                  0
# NombreJob                                  0
# dtype: int64
#      satus_implantation                   table secundary_table  \
# 1040          DELIVERED  t_p68x_queue_hierarchy             NaN
# 1041          DELIVERED  t_p68x_queue_hierarchy             NaN
#
#             conf_type                                conf version  \
# 1040  Url Artifactory   P68X_queue-hierarchy_MRField.conf  13.0.3
# 1041  Url Artifactory  P68X_queue-hierarchy_MRObject.conf  13.0.3
#
#                                               ConfigURL Extralibs  \
# 1040  https://artifactory.globaldevtools.bbva.com/ui...       NaN
# 1041  https://artifactory.globaldevtools.bbva.com/ui...       NaN
#
#      implantation  version_simple               unique_id  \
# 1040        Local            1303   queuehierarchymrfield
# 1041        Local            1303  queuehierarchymrobject
#
#                                     NombreJob  len_unique_id
# 1040   p68x-gl-hmm-qlt-queuehierarchymrfield-             21
# 1041  p68x-gl-hmm-qlt-queuehierarchymrobject-             22

# %%
wip['table'].map(dict_tablas).fillna('')
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 1037
# 1038
# 1039
# 1040
# 1041
# Name: table, Length: 1042, dtype: object

# %%
version = wip.sort_values('version_simple',ascending=False).version.unique()
print(version)
# Out:
# ['17.3.0' '17.2.0' '17.1.0' '17.0.2' '17.0.1' '17.0.0' '16.1.7' '16.1.6'
#  '16.1.5' '16.1.4' '16.1.3' '16.1.2' '16.1.1' '16.1.0' '16.0.9' '16.0.8'
#  '16.0.7' '16.0.6' '16.0.5' '16.0.4' '16.0.3' '16.0.2' '16.0.1' '16.0.0'
#  '15.1.1' '15.1.0' '15.0.5' '15.0.4' '15.0.3' '15.0.2' '15.0.1' '15.0.0'
#  '14.1.1' '14.1.0' '14.0.7' '14.0.3' '14.0.0' '13.1.0' '13.0.3']

# %% [markdown]
# No puede ser mayor a 27

# %%
print(wip['len_unique_id'].max())
# Out:
# 27

# %%
wip_confs = wip.sort_values(by='version_simple',ascending=False)[['implantation','conf','ConfigURL','Extralibs','NombreJob','version','version_simple']]

wip_confs['Extralibs'] = np.where(
    wip_confs['conf'].duplicated(keep=False),
    wip_confs.merge(wip_confs.dropna(subset=['conf','Extralibs']).rename(columns={'Extralibs':'Extralibs1'}).drop_duplicates('conf'),how='left', on='conf').Extralibs1,
    wip_confs['Extralibs']
    )

wip_confs = wip_confs.drop_duplicates(subset=['conf']).reset_index(drop=True)

wip_confs['NombreJobFinal'] = np.where(
    wip_confs['NombreJob'].duplicated(keep=False),
    wip_confs['NombreJob'] + '0' + wip_confs.groupby('NombreJob').cumcount().add(1).astype(str).str[-2:],
    wip_confs['NombreJob'] + '01'
    )
wip_confs = wip_confs.drop(columns=['NombreJob'])
wip_confs['UA'] = wip_confs['conf'].str[:4].str.lower()
wip_confs['len_NombreJobFinal'] = wip_confs.NombreJobFinal.str.len()

if not UUAAs:
    UUAAs = list(wip_confs.conf.str[:4].str.lower().sort_values().unique())
wip_confs.query('UA == @UUAAs', inplace=True) #nos quedamos con nuestras UUAAs

wip_confs
# Out:
#     implantation                                               conf  \
# 0          Local               KSZG_trnslty-by-channel_MRField.conf
# 1          Local          P6R1_prt-cont-prdt-bal-board_MRField.conf
# 2           Both  G5M3_agg-mlzed-amount_SCAT_sustainability-hier...
# 51          Both                 G5M3_agg-mlzed-amount_MRField.conf
# 60       Holding          G5M3_sust-mob-operations-cib_MRField.conf
# 160        Local              G5M3_sust-mob-operations_MRField.conf
# 167        Local          G5M3_sust-mob-operations-eod_MRField.conf
# 213        Local                KSZG_queue-controller_MRObject.conf
# 214        Local                 KSZG_queue-controller_MRField.conf
# 219        Local       G5M3_movement-carbon-footprint_MRObject.conf
# 222        Local        G5M3_movement-carbon-footprint_MRField.conf
# 223      Holding  G5M3_sust-mob-operations-cib_G5M3_sust-mob-ope...
# 239        Local              KSZG_trnslty-by-channel_MRObject.conf
# 254        Local  G5M3_movement-carbon-footprint_KMOL_account-mo...
# 255        Local  G5M3_movement-carbon-footprint_KCOG_entity_MMR...
# 256        Local  G5M3_movement-carbon-footprint_KCOG_country_MM...
# 274        Local  KSZG_trnslty-by-channel_KCOG_currency_MMRule.conf
# 275        Local    KSZG_trnslty-by-channel_KCOG_branch_MMRule.conf
# 276        Local    KSZG_trnslty-by-channel_KCOG_entity_MMRule.conf
# 277        Local   KSZG_trnslty-by-channel_KCOG_country_MMRule.conf
# 278        Local      KSZG_queue-controller_KCOG_branch_MMRule.conf
# 279        Local      KSZG_queue-controller_KCOG_entity_MMRule.conf
# 280        Local     KSZG_queue-controller_KCOG_country_MMRule.conf
# 318        Local  KSZG_trnslty-by-channel_KSAN_contract-global-l...
# 446      Holding         G5M3_sust-mob-operations-cib_MRObject.conf
# 447        Local             G5M3_sust-mob-operations_MRObject.conf
# 475        Local  G5M3_sust-mob-operations_KSAN_contract-global-...
# 486        Local  KSZG_queue-controller_KBTQ_role-person_MMRule....
# 523        Local  G5M3_sust-mob-operations-eod_KSAN_contract-glo...
# 524        Local         G5M3_sust-mob-operations-eod_MRObject.conf
# 577        Local           P6R1_interaction-by-channel_MRField.conf
# 590        Local        P6R1_customer-socio-demo-board_MRField.conf
# 607        Local                   P6R1_movements-hist_MRField.conf
# 612      Holding  G5M3_sust-mob-operations-cib_KCOG_entity_MMRul...
#
#                                              ConfigURL  \
# 0    https://artifactory.globaldevtools.bbva.com/ui...
# 1    https://artifactory.globaldevtools.bbva.com/ui...
# 2    https://artifactory.globaldevtools.bbva.com/ui...
# 51   https://artifactory.globaldevtools.bbva.com/ui...
# 60   https://artifactory.globaldevtools.bbva.com/ui...
# 160  https://artifactory.globaldevtools.bbva.com/ui...
# 167  https://artifactory.globaldevtools.bbva.com/ui...
# 213  https://artifactory.globaldevtools.bbva.com/ui...
# 214  https://artifactory.globaldevtools.bbva.com/ui...
# 219  https://artifactory.globaldevtools.bbva.com/ui...
# 222  https://artifactory.globaldevtools.bbva.com/ui...
# 223  https://artifactory.globaldevtools.bbva.com/ui...
# 239  https://artifactory.globaldevtools.bbva.com/ui...
# 254  https://artifactory.globaldevtools.bbva.com/ui...
# 255  https://artifactory.globaldevtools.bbva.com/ui...
# 256  https://artifactory.globaldevtools.bbva.com/ui...
# 274  https://artifactory.globaldevtools.bbva.com/ui...
# 275  https://artifactory.globaldevtools.bbva.com/ui...
# 276  https://artifactory.globaldevtools.bbva.com/ui...
# 277  https://artifactory.globaldevtools.bbva.com/ui...
# 278  https://artifactory.globaldevtools.bbva.com/ui...
# 279  https://artifactory.globaldevtools.bbva.com/ui...
# 280  https://artifactory.globaldevtools.bbva.com/ui...
# 318  https://artifactory.globaldevtools.bbva.com/ui...
# 446  https://artifactory.globaldevtools.bbva.com/ui...
# 447  https://artifactory.globaldevtools.bbva.com/ui...
# 475  https://artifactory.globaldevtools.bbva.com/ui...
# 486  https://artifactory.globaldevtools.bbva.com/ui...
# 523  https://artifactory.globaldevtools.bbva.com/ui...
# 524  https://artifactory.globaldevtools.bbva.com/ui...
# 577  https://artifactory.globaldevtools.bbva.com/ui...
# 590  https://artifactory.globaldevtools.bbva.com/ui...
# 607  https://artifactory.globaldevtools.bbva.com/ui...
# 612  https://artifactory.globaldevtools.bbva.com/ui...
#
#                                              Extralibs version  \
# 0                                                  NaN  17.3.0
# 1                                                  NaN  17.3.0
# 2                                                  NaN  17.3.0
# 51                                                 NaN  17.0.0
# 60                                                 NaN  16.1.7
# 160                                                NaN  16.0.5
# 167                                                NaN  16.0.5
# 213                                                NaN  15.1.0
# 214                                                NaN  15.1.0
# 219                                                NaN  15.1.0
# 222                                                NaN  15.1.0
# 223  https://artifactory-gdt.central-01.nextgen.igr...  15.1.0
# 239                                                NaN  15.1.0
# 254                                                NaN  15.1.0
# 255                                                NaN  15.1.0
# 256                                                NaN  15.1.0
# 274                                                NaN  15.1.0
# 275                                                NaN  15.1.0
# 276                                                NaN  15.1.0
# 277                                                NaN  15.1.0
# 278                                                NaN  15.1.0
# 279                                                NaN  15.1.0
# 280                                                NaN  15.1.0
# 318                                                NaN  15.1.0
# 446                                                NaN  15.1.0
# 447                                                NaN  15.1.0
# 475                                                NaN  15.1.0
# 486                                                NaN  15.1.0
# 523                                                NaN  15.1.0
# 524                                                NaN  15.1.0
# 577                                                NaN  15.1.0
# 590                                                NaN  15.1.0
# 607                                                NaN  15.1.0
# 612                                                NaN  15.1.0
#
#      version_simple                                  NombreJobFinal    UA  \
# 0              1730      kszg-gl-hmm-qlt-trnsltybychannelmrfield-01  kszg
# 1              1730   p6r1-gl-hmm-qlt-prtcontprdtbalboardmrfield-01  p6r1
# 2              1730         g5m3-gl-hmm-qlt-aggmlzedamountmmrule-01  g5m3
# 51             1700        g5m3-gl-hmm-qlt-aggmlzedamountmrfield-01  g5m3
# 60             1617   g5m3-gl-hmm-qlt-sustmoboperationscimrfield-01  g5m3
# 160            1605     g5m3-gl-hmm-qlt-sustmoboperationsmrfield-01  g5m3
# 167            1605   g5m3-gl-hmm-qlt-sustmoboperationseomrfield-01  g5m3
# 213            1510      kszg-gl-hmm-qlt-queuecontrollermrobject-01  kszg
# 214            1510       kszg-gl-hmm-qlt-queuecontrollermrfield-01  kszg
# 219            1510  g5m3-gl-hmm-qlt-movementcarbonfootpmrobject-01  g5m3
# 222            1510   g5m3-gl-hmm-qlt-movementcarbonfootpmrfield-01  g5m3
# 223            1510    g5m3-gl-hmm-qlt-sustmoboperationscimmrule-01  g5m3
# 239            1510     kszg-gl-hmm-qlt-trnsltybychannelmrobject-01  kszg
# 254            1510    g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-01  g5m3
# 255            1510    g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-02  g5m3
# 256            1510    g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-03  g5m3
# 274            1510       kszg-gl-hmm-qlt-trnsltybychannelmmrule-01  kszg
# 275            1510       kszg-gl-hmm-qlt-trnsltybychannelmmrule-02  kszg
# 276            1510       kszg-gl-hmm-qlt-trnsltybychannelmmrule-03  kszg
# 277            1510       kszg-gl-hmm-qlt-trnsltybychannelmmrule-04  kszg
# 278            1510        kszg-gl-hmm-qlt-queuecontrollermmrule-01  kszg
# 279            1510        kszg-gl-hmm-qlt-queuecontrollermmrule-02  kszg
# 280            1510        kszg-gl-hmm-qlt-queuecontrollermmrule-03  kszg
# 318            1510       kszg-gl-hmm-qlt-trnsltybychannelmmrule-05  kszg
# 446            1510  g5m3-gl-hmm-qlt-sustmoboperationscimrobject-01  g5m3
# 447            1510    g5m3-gl-hmm-qlt-sustmoboperationsmrobject-01  g5m3
# 475            1510      g5m3-gl-hmm-qlt-sustmoboperationsmmrule-01  g5m3
# 486            1510        kszg-gl-hmm-qlt-queuecontrollermmrule-04  kszg
# 523            1510    g5m3-gl-hmm-qlt-sustmoboperationseommrule-01  g5m3
# 524            1510  g5m3-gl-hmm-qlt-sustmoboperationseomrobject-01  g5m3
# 577            1510   p6r1-gl-hmm-qlt-interactionbychannemrfield-01  p6r1
# 590            1510   p6r1-gl-hmm-qlt-customersociodemobomrfield-01  p6r1
# 607            1510         p6r1-gl-hmm-qlt-movementshistmrfield-01  p6r1
# 612            1510    g5m3-gl-hmm-qlt-sustmoboperationscimmrule-02  g5m3
#
#      len_NombreJobFinal
# 0                    42
# 1                    45
# 2                    39
# 51                   40
# 60                   45
# 160                  43
# 167                  45
# 213                  42
# 214                  41
# 219                  46
# 222                  45
# 223                  44
# 239                  43
# 254                  44
# 255                  44
# 256                  44
# 274                  41
# 275                  41
# 276                  41
# 277                  41
# 278                  40
# 279                  40
# 280                  40
# 318                  41
# 446                  46
# 447                  44
# 475                  42
# 486                  40
# 523                  44
# 524                  46
# 577                  45
# 590                  45
# 607                  39
# 612                  44

# %%
print(set(wip_confs.UA.unique()))
print('\n¿Mismas UUAAs? en wip_confs:')

print(set(wip_confs.UA.unique()) == set(UUAAs))
# Out:
# {'kszg', 'g5m3', 'p6r1'}
#
# ¿Mismas UUAAs? en wip_confs:
# True

# %% [markdown]
# No puede ser mayor a 41+5 separadores: 46

# %%
print(wip_confs['len_NombreJobFinal'].max())
# Out:
# 46

# %% [markdown]
# Revisamos ramas de cada directorio y creamos directorios

# %%
#Revisamos rama de cada directorio
ruta_confs = "C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/{}/glgldh360gloqlt/"
ramas = []
print(UUAAs)
for UA in UUAAs:
    print('- ',UA)
    ruta_ua = ruta_confs.format(UA)
    git = 'git -C {0} rev-parse --abbrev-ref HEAD'.format(ruta_ua)
    rama = str(os.popen(git).read()).strip()
    ramas.append(rama)
    print(rama)
    # if not os.path.exists(ruta_ua+'/hammurabi/jobs/'):
    #     os.makedirs(ruta_ua+'/hammurabi/jobs/')
# Out:
# ['kszg', 'p6r1', 'g5m3']
# -  kszg
# feature/MVP_3Q25_c360_17_07_2025
# -  p6r1
# feature/MVP_3Q25_c360_17_07_2025
# -  g5m3
# feature/MVP_3Q25_c360_17_07_2025

# %%
print('ramas unicas (siempre debemos actuar sobre una)')
print(list(np.unique(ramas)))
# Out:
# ramas unicas (siempre debemos actuar sobre una)
# [np.str_('feature/MVP_3Q25_c360_17_07_2025')]

# %%
#Reseteamos directorios (eliminamos y volvemos a crear)
ruta_confs = "C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/{}/glgldh360gloqlt/"
geo_ruta_dict = {
    'europa': '01',
    'america':'02',
    'america-ada':'02'
    }
print(UUAAs)
for UA in UUAAs:
    print(UA)
    ruta_ua = ruta_confs.format(UA)
    shutil.rmtree(ruta_ua+'/hammurabi/jobs/')
    for geo_ruta in geo_ruta_dict.keys():
        os.makedirs(ruta_ua+'/hammurabi/jobs/'+geo_ruta)
# Out:
# ['kszg', 'p6r1', 'g5m3']
# kszg
# p6r1
# g5m3

# %% [markdown]
# Creamos jobs en cada directorio

# %%
version_desplegada_UA = wip_confs.sort_values('version_simple',ascending=False).drop_duplicates('UA')[['UA','version']].rename(columns={'version':'version_despliegue'})
wip_confs = wip_confs.merge(version_desplegada_UA,how='left',on='UA')
version_desplegada_UA
# Out:
#      UA version_despliegue
# 0  kszg             17.3.0
# 1  p6r1             17.3.0
# 2  g5m3             17.3.0

# %%
print("mismas uuaas? \nversion_desplegada_UA")

set(version_desplegada_UA.UA) == set(UUAAs)
# Out:
# mismas uuaas?
# version_desplegada_UA
# True

# %%
print('UUAAs afectadas:')
print(sorted(set(wip_confs.UA.unique())))
print("\nmismas uuaas? \nwip_confs")

set(wip_confs.UA.unique()) == set(UUAAs)
# Out:
# UUAAs afectadas:
# ['g5m3', 'kszg', 'p6r1']
#
# mismas uuaas?
# wip_confs
# True

# %%
extralib_confs = wip_confs.dropna(subset='Extralibs')
other_confs = wip_confs[wip_confs.Extralibs.isnull()]

# %%
#SI HEMOS CREADO UN NUEVO REPO INCLUIR EN './repos/repos.csv' desde https://docs.google.com/spreadsheets/d/1aLELrHoXPwm8CSY2a6DN6DRqoIkruHQO37JrQcaZFNM/edit?gid=1588638166#gid=1588638166
uuaas_repos = pd.read_csv('./repos/repos.csv')
uuaas_repos.UUAA = uuaas_repos.UUAA.str.lower()
uuaas_repos.index = uuaas_repos.UUAA
dict_project_ua = uuaas_repos.project.to_dict()

# %%
for ua in UUAAs:
    print(ua,'- ¿Está en el inventario de repos? ("repos\\repos.csv"):\n', ua in list(uuaas_repos.UUAA))
    if not ua in list(uuaas_repos.UUAA):
        print("\t¡ATENCIÓN! Añadir UA {0} a 'repos\\repos.csv'".format(ua))
# Out:
# kszg - ¿Está en el inventario de repos? ("repos\repos.csv"):
#  True
# p6r1 - ¿Está en el inventario de repos? ("repos\repos.csv"):
#  True
# g5m3 - ¿Está en el inventario de repos? ("repos\repos.csv"):
#  True

# %%
geo_ruta_dict
# Out:
# {'europa': '01', 'america': '02', 'america-ada': '02'}

# %%
geos = ["gl"]#,"es","co","pe","ar","mx"]
conf_job_dict = {}
#Extralibs
for index, row in extralib_confs.iterrows():
    for geo in geos:
        for geo_ruta in geo_ruta_dict.keys():
            if row["implantation"]=="Holding":
                geo = "gl"
            nombre_job = row['NombreJobFinal']
            nombre_job = nombre_job[0:5] + geo + nombre_job[7:]
            ruta_ua = ruta_confs.format(row['UA'])
            if geo_ruta == 'europa': #para europa, nuevo formato ADA
                extralib_job_eur['description'] = nombre_job
                extralib_job_eur['jobName'] = nombre_job
                extralib_job_eur['params']['metaConfig'] = "gl:" + row['UA'] + ":" + "glgldh360gloqlt" + ":" + row['conf'].replace('.conf','') + ":" + row['version']
                extralib_job_eur['params']['extraLibs'] = row['Extralibs'].replace('https://artifactory.globaldevtools.bbva.com/ui/repos/tree/General/','s3://ada-eu-south-2-core-live-artifacts/dataproc/migration-artifacts/artifactory/'.format(geo_ruta_dict[geo_ruta]))
                extralib_job_eur['params']['extraLibs'] = row['Extralibs'].replace('https://artifactory-gdt.central-01.nextgen.igrupobbva/artifactory/','s3://ada-eu-south-2-core-live-artifacts/dataproc/migration-artifacts/artifactory/'.format(geo_ruta_dict[geo_ruta]))
                extralib_job = extralib_job_eur
            elif geo_ruta == 'america-ada': #para america-ada, nuevo formato ADA
                nombre_job_ada = row['NombreJobFinal']
                extralib_job_eur['description'] = nombre_job
                extralib_job_eur['jobName'] = nombre_job
                extralib_job_eur['params']['metaConfig'] = "gl:" + row['UA'] + ":" + "glgldh360gloqlt" + ":" + row['conf'].replace('.conf','') + ":" + row['version']
                extralib_job_eur['params']['extraLibs'] = row['Extralibs'].replace('https://artifactory.globaldevtools.bbva.com/ui/repos/tree/General/','s3://ada-us-east-1-core-live-artifacts/dataproc/migration-artifacts/artifactory/'.format(geo_ruta_dict[geo_ruta]))
                extralib_job_eur['params']['extraLibs'] = row['Extralibs'].replace('https://artifactory-gdt.central-01.nextgen.igrupobbva/artifactory/','s3://ada-us-east-1-core-live-artifacts/dataproc/migration-artifacts/artifactory/'.format(geo_ruta_dict[geo_ruta]))
                extralib_job = extralib_job_eur
            elif geo_ruta == 'america': #para america, por ahora seguimos igual
                extralib_job_ame['description'] = nombre_job
                extralib_job_ame['_id'] = nombre_job
                extralib_job_ame['params']['configUrl'] = row['ConfigURL'].replace('https://artifactory.globaldevtools.bbva.com/ui/repos/tree/General/','https://artifactory-gdt.central-{0}.nextgen.igrupobbva/artifactory/'.format(geo_ruta_dict[geo_ruta]))
                extralib_job_ame['params']['extraLibs'] = row['Extralibs'].replace('https://artifactory.globaldevtools.bbva.com/ui/repos/tree/General/','https://artifactory-gdt.central-{0}.nextgen.igrupobbva/artifactory/'.format(geo_ruta_dict[geo_ruta]))
                extralib_job_ame['params']['extraLibs'] = row['Extralibs'].replace('https://artifactory-gdt.central-01.nextgen.igrupobbva/artifactory/','https://artifactory-gdt.central-{0}.nextgen.igrupobbva/artifactory/'.format(geo_ruta_dict[geo_ruta]))
                extralib_job = extralib_job_ame
            with open(ruta_ua + '/hammurabi/jobs/' + geo_ruta + '/' + nombre_job + '.json', 'w', encoding='utf-8') as f:
                json.dump(extralib_job, f, ensure_ascii=False, indent=4)
            print(ruta_ua + '/hammurabi/jobs/' + geo_ruta + '/' + nombre_job + '.json')

        if not version_personalizada:
            conf_job_dict[row['conf']] = (
                "https://bitbucket.globaldevtools.bbva.com/bitbucket/projects/" + dict_project_ua[row['UA']] + "/repos/glgldh360gloqlt/browse/hammurabi/jobs/"+list(geo_ruta_dict.keys())[0]+'/'+nombre_job+".json"+"?at=refs%2Ftags%2Fv"+row['version_despliegue'] + "\n"
                "https://bitbucket.globaldevtools.bbva.com/bitbucket/projects/" + dict_project_ua[row['UA']] + "/repos/glgldh360gloqlt/browse/hammurabi/jobs/"+list(geo_ruta_dict.keys())[1]+'/'+nombre_job+".json"+"?at=refs%2Ftags%2Fv"+row['version_despliegue']
                )
        else:
            conf_job_dict[row['conf']] = (
                "https://bitbucket.globaldevtools.bbva.com/bitbucket/projects/" + dict_project_ua[row['UA']] + "/repos/glgldh360gloqlt/browse/hammurabi/jobs/"+list(geo_ruta_dict.keys())[0]+'/'+nombre_job+".json"+"?at=refs%2Ftags%2Fv"+version_personalizada + "\n"
                "https://bitbucket.globaldevtools.bbva.com/bitbucket/projects/" + dict_project_ua[row['UA']] + "/repos/glgldh360gloqlt/browse/hammurabi/jobs/"+list(geo_ruta_dict.keys())[1]+'/'+nombre_job+".json"+"?at=refs%2Ftags%2Fv"+version_personalizada   
                )

#Others
for index, row in other_confs.iterrows():
    for geo in geos:
        for geo_ruta in geo_ruta_dict.keys():
            if row["implantation"]=="Holding":
                geo = "gl"
            nombre_job = row['NombreJobFinal']
            nombre_job = nombre_job[0:5] + geo + nombre_job[7:]
            ruta_ua = ruta_confs.format(row['UA'])
            if geo_ruta == 'europa':        #para europa, nuevo formato ADA
                other_job_eur['description'] = nombre_job
                other_job_eur['jobName'] = nombre_job
                other_job_eur['params']['metaConfig'] = "gl:" + row['UA'] + ":" + "glgldh360gloqlt" + ":" + row['conf'].replace('.conf','') + ":" + row['version']
                other_job = other_job_eur
            elif geo_ruta == 'america-ada': #para europa, nuevo formato ADA
                nombre_job = row['NombreJobFinal']
                other_job_eur['description'] = nombre_job
                other_job_eur['jobName'] = nombre_job
                other_job_eur['params']['metaConfig'] = "gl:" + row['UA'] + ":" + "glgldh360gloqlt" + ":" + row['conf'].replace('.conf','') + ":" + row['version']
                other_job = other_job_eur
            elif geo_ruta == 'america':     #para america, por ahora seguimos igual
                other_job_ame['description'] = nombre_job
                other_job_ame['_id'] = nombre_job
                other_job_ame['params']['configUrl'] = row['ConfigURL'].replace('https://artifactory.globaldevtools.bbva.com/ui/repos/tree/General/','https://artifactory-gdt.central-{0}.nextgen.igrupobbva/artifactory/'.format(geo_ruta_dict[geo_ruta]))
                other_job = other_job_ame
            with open(ruta_ua + '/hammurabi/jobs/' + geo_ruta + '/' + nombre_job + '.json', 'w', encoding='utf-8') as f:
                json.dump(other_job, f, ensure_ascii=False, indent=4)
            print(ruta_ua + '/hammurabi/jobs/' + geo_ruta + '/' + nombre_job + '.json')

        if not version_personalizada:
            conf_job_dict[row['conf']] = (
                "https://bitbucket.globaldevtools.bbva.com/bitbucket/projects/" + dict_project_ua[row['UA']] + "/repos/glgldh360gloqlt/browse/hammurabi/jobs/"+list(geo_ruta_dict.keys())[0]+'/'+nombre_job+".json"+"?at=refs%2Ftags%2Fv"+row['version_despliegue'] + "\n"
                "https://bitbucket.globaldevtools.bbva.com/bitbucket/projects/" + dict_project_ua[row['UA']] + "/repos/glgldh360gloqlt/browse/hammurabi/jobs/"+list(geo_ruta_dict.keys())[1]+'/'+nombre_job+".json"+"?at=refs%2Ftags%2Fv"+row['version_despliegue']
                )
        else:
            conf_job_dict[row['conf']] = (
                "https://bitbucket.globaldevtools.bbva.com/bitbucket/projects/" + dict_project_ua[row['UA']] + "/repos/glgldh360gloqlt/browse/hammurabi/jobs/"+list(geo_ruta_dict.keys())[0]+'/'+nombre_job+".json"+"?at=refs%2Ftags%2Fv"+version_personalizada + "\n"
                "https://bitbucket.globaldevtools.bbva.com/bitbucket/projects/" + dict_project_ua[row['UA']] + "/repos/glgldh360gloqlt/browse/hammurabi/jobs/"+list(geo_ruta_dict.keys())[1]+'/'+nombre_job+".json"+"?at=refs%2Ftags%2Fv"+version_personalizada   
                )
# Out:
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-sustmoboperationscimmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-sustmoboperationscimmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-sustmoboperationscimmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-trnsltybychannelmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-trnsltybychannelmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-trnsltybychannelmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/europa/p6r1-gl-hmm-qlt-prtcontprdtbalboardmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/america/p6r1-gl-hmm-qlt-prtcontprdtbalboardmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/america-ada/p6r1-gl-hmm-qlt-prtcontprdtbalboardmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-aggmlzedamountmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-aggmlzedamountmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-aggmlzedamountmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-aggmlzedamountmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-aggmlzedamountmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-aggmlzedamountmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-sustmoboperationscimrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-sustmoboperationscimrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-sustmoboperationscimrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-sustmoboperationsmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-sustmoboperationsmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-sustmoboperationsmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-sustmoboperationseomrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-sustmoboperationseomrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-sustmoboperationseomrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-queuecontrollermrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-queuecontrollermrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-queuecontrollermrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-queuecontrollermrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-queuecontrollermrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-queuecontrollermrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-movementcarbonfootpmrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-movementcarbonfootpmrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-movementcarbonfootpmrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-movementcarbonfootpmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-movementcarbonfootpmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-movementcarbonfootpmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-trnsltybychannelmrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-trnsltybychannelmrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-trnsltybychannelmrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-03.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-03.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-03.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-trnsltybychannelmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-trnsltybychannelmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-trnsltybychannelmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-trnsltybychannelmmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-trnsltybychannelmmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-trnsltybychannelmmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-trnsltybychannelmmrule-03.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-trnsltybychannelmmrule-03.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-trnsltybychannelmmrule-03.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-trnsltybychannelmmrule-04.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-trnsltybychannelmmrule-04.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-trnsltybychannelmmrule-04.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-queuecontrollermmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-queuecontrollermmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-queuecontrollermmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-queuecontrollermmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-queuecontrollermmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-queuecontrollermmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-queuecontrollermmrule-03.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-queuecontrollermmrule-03.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-queuecontrollermmrule-03.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-trnsltybychannelmmrule-05.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-trnsltybychannelmmrule-05.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-trnsltybychannelmmrule-05.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-sustmoboperationscimrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-sustmoboperationscimrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-sustmoboperationscimrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-sustmoboperationsmrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-sustmoboperationsmrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-sustmoboperationsmrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-sustmoboperationsmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-sustmoboperationsmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-sustmoboperationsmmrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/europa/kszg-gl-hmm-qlt-queuecontrollermmrule-04.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america/kszg-gl-hmm-qlt-queuecontrollermmrule-04.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/kszg/glgldh360gloqlt//hammurabi/jobs/america-ada/kszg-gl-hmm-qlt-queuecontrollermmrule-04.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-sustmoboperationseommrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-sustmoboperationseommrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-sustmoboperationseommrule-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-sustmoboperationseomrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-sustmoboperationseomrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-sustmoboperationseomrobject-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/europa/p6r1-gl-hmm-qlt-interactionbychannemrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/america/p6r1-gl-hmm-qlt-interactionbychannemrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/america-ada/p6r1-gl-hmm-qlt-interactionbychannemrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/europa/p6r1-gl-hmm-qlt-customersociodemobomrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/america/p6r1-gl-hmm-qlt-customersociodemobomrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/america-ada/p6r1-gl-hmm-qlt-customersociodemobomrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/europa/p6r1-gl-hmm-qlt-movementshistmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/america/p6r1-gl-hmm-qlt-movementshistmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/p6r1/glgldh360gloqlt//hammurabi/jobs/america-ada/p6r1-gl-hmm-qlt-movementshistmrfield-01.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/europa/g5m3-gl-hmm-qlt-sustmoboperationscimmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america/g5m3-gl-hmm-qlt-sustmoboperationscimmrule-02.json
# C:/Users/O005820/Documents/repositorios/GDH_c360_hammurabi_UUAAs/g5m3/glgldh360gloqlt//hammurabi/jobs/america-ada/g5m3-gl-hmm-qlt-sustmoboperationscimmrule-02.json

# %%
conf_url_OLD = pd.read_csv('wip_conf_url_OLD.csv',sep=',')
conf_url_OLD['UA'] = conf_url_OLD.conf.str[:4].str.lower()
conf_url_OLD.query('UA != @UUAAs',inplace=True)
print("UUAAs NO afectadas:\n",list(conf_url_OLD.UA.sort_values().unique()))
print("UUAAs SI afectadas:\n",UUAAs)
#personalizar eliminación
# conf_url_OLD.query('UA != "ksci"',inplace=True)
conf_url_OLD.drop(columns='UA',inplace=True)

conf_url_OLD
# Out:
# UUAAs NO afectadas:
#  ['b0hn', 'cgj7', 'cmov', 'ctar', 'dast', 'dtau', 'ejb6', 'fzpd', 'j7il', 'katc', 'kcdg', 'kceg', 'kcpg', 'kctd', 'kfcm', 'kmig', 'knfa', 'kpan', 'ksrr', 'kstb', 'kusu', 'kwth', 'l9ct', 'l9sv', 'msx9', 'nm7r', 'nols', 'p68x', 'r4fu', 're4m', 'rzua', 'scat', 'tdi3', 'tlhr', 'yfvh']
# UUAAs SI afectadas:
#  ['kszg', 'p6r1', 'g5m3']
#                                                   conf  \
# 0                 B0HN_agg-output-ems-hgl_MRField.conf
# 1                B0HN_agg-output-ems-hgl_MRObject.conf
# 2    B0HN_agg-output-ems-hgl_KSAG_holding-business-...
# 3                    B0HN_sust-group-mark_MRField.conf
# 4                   B0HN_sust-group-mark_MRObject.conf
# ..                                                 ...
# 838             YFVH_cards-calc-balances_MRObject.conf
# 839  YFVH_cards-calc-balances_KCOG_country_MMRule.conf
# 840   YFVH_cards-calc-balances_KCOG_entity_MMRule.conf
# 841  YFVH_cards-calc-balances_KCOG_currency_MMRule....
# 842  YFVH_cards-calc-balances_KSAN_contract-global-...
#
#                                                job_url  \
# 0    https://bitbucket.globaldevtools.bbva.com/bitb...
# 1    https://bitbucket.globaldevtools.bbva.com/bitb...
# 2    https://bitbucket.globaldevtools.bbva.com/bitb...
# 3    https://bitbucket.globaldevtools.bbva.com/bitb...
# 4    https://bitbucket.globaldevtools.bbva.com/bitb...
# ..                                                 ...
# 838  https://bitbucket.globaldevtools.bbva.com/bitb...
# 839  https://bitbucket.globaldevtools.bbva.com/bitb...
# 840  https://bitbucket.globaldevtools.bbva.com/bitb...
# 841  https://bitbucket.globaldevtools.bbva.com/bitb...
# 842  https://bitbucket.globaldevtools.bbva.com/bitb...
#
#                           table                secundary_table  \
# 0     t_b0hn_agg_output_ems_hgl                            NaN
# 1     t_b0hn_agg_output_ems_hgl                            NaN
# 2     t_b0hn_agg_output_ems_hgl  t_ksag_holding_business_group
# 3        t_b0hn_sust_group_mark                            NaN
# 4        t_b0hn_sust_group_mark                            NaN
# ..                          ...                            ...
# 838  t_yfvh_cards_calc_balances                            NaN
# 839  t_yfvh_cards_calc_balances                 t_kcog_country
# 840  t_yfvh_cards_calc_balances                  t_kcog_entity
# 841  t_yfvh_cards_calc_balances                t_kcog_currency
# 842  t_yfvh_cards_calc_balances   t_ksan_contract_global_local
#
#                                                    job   version
# 0       b0hn-gl-hmm-qlt-aggoutputemshglmrfield-01.json  "17.2.0"
# 1      b0hn-gl-hmm-qlt-aggoutputemshglmrobject-01.json  "17.2.0"
# 2        b0hn-gl-hmm-qlt-aggoutputemshglmmrule-01.json  "17.2.0"
# 3         b0hn-gl-hmm-qlt-sustgroupmarkmrfield-01.json  "17.2.0"
# 4        b0hn-gl-hmm-qlt-sustgroupmarkmrobject-01.json  "17.2.0"
# ..                                                 ...       ...
# 838  yfvh-gl-hmm-qlt-cardscalcbalancesmrobject-01.json  "16.1.5"
# 839    yfvh-gl-hmm-qlt-cardscalcbalancesmmrule-01.json  "16.1.5"
# 840    yfvh-gl-hmm-qlt-cardscalcbalancesmmrule-02.json  "16.1.5"
# 841    yfvh-gl-hmm-qlt-cardscalcbalancesmmrule-03.json  "16.1.5"
# 842    yfvh-gl-hmm-qlt-cardscalcbalancesmmrule-04.json  "16.1.5"
#
# [809 rows x 6 columns]

# %%
conf_url_NEW = pd.DataFrame(conf_job_dict.items(), columns=['conf', 'job_url']).merge(wip[['table','secundary_table','conf']].drop_duplicates(subset='conf').dropna(subset=['table','conf']),how='left',on='conf')
conf_url_NEW['job'] = conf_url_NEW.job_url.apply(lambda x: x.split('/')[-1])
conf_url_NEW['job'] = conf_url_NEW.job.apply(lambda x: x.split('?')[0])
conf_url_NEW['version'] = conf_url_NEW.job_url.str[-6:]
conf_url = pd.concat([conf_url_OLD,conf_url_NEW],axis=0)
conf_url['version'] = '"' + conf_url['version'].str.replace('"','') + '"'
conf_url['type'] = conf_url.conf.str.extract(r'_(.{6,8}).conf').replace({'MRField':1, 'MRObject':2, 'MMRule':3})
conf_url.sort_values(['table','type'], inplace=True)
conf_url.drop(columns='type', inplace=True)
conf_url.to_csv('wip_conf_url_NEW.csv',sep=';',index=False)
conf_url
# Out:
#                                                   conf  \
# 0                 B0HN_agg-output-ems-hgl_MRField.conf
# 1                B0HN_agg-output-ems-hgl_MRObject.conf
# 2    B0HN_agg-output-ems-hgl_KSAG_holding-business-...
# 3                    B0HN_sust-group-mark_MRField.conf
# 4                   B0HN_sust-group-mark_MRObject.conf
# ..                                                 ...
# 838             YFVH_cards-calc-balances_MRObject.conf
# 839  YFVH_cards-calc-balances_KCOG_country_MMRule.conf
# 840   YFVH_cards-calc-balances_KCOG_entity_MMRule.conf
# 841  YFVH_cards-calc-balances_KCOG_currency_MMRule....
# 842  YFVH_cards-calc-balances_KSAN_contract-global-...
#
#                                                job_url  \
# 0    https://bitbucket.globaldevtools.bbva.com/bitb...
# 1    https://bitbucket.globaldevtools.bbva.com/bitb...
# 2    https://bitbucket.globaldevtools.bbva.com/bitb...
# 3    https://bitbucket.globaldevtools.bbva.com/bitb...
# 4    https://bitbucket.globaldevtools.bbva.com/bitb...
# ..                                                 ...
# 838  https://bitbucket.globaldevtools.bbva.com/bitb...
# 839  https://bitbucket.globaldevtools.bbva.com/bitb...
# 840  https://bitbucket.globaldevtools.bbva.com/bitb...
# 841  https://bitbucket.globaldevtools.bbva.com/bitb...
# 842  https://bitbucket.globaldevtools.bbva.com/bitb...
#
#                           table                secundary_table  \
# 0     t_b0hn_agg_output_ems_hgl                            NaN
# 1     t_b0hn_agg_output_ems_hgl                            NaN
# 2     t_b0hn_agg_output_ems_hgl  t_ksag_holding_business_group
# 3        t_b0hn_sust_group_mark                            NaN
# 4        t_b0hn_sust_group_mark                            NaN
# ..                          ...                            ...
# 838  t_yfvh_cards_calc_balances                            NaN
# 839  t_yfvh_cards_calc_balances                 t_kcog_country
# 840  t_yfvh_cards_calc_balances                  t_kcog_entity
# 841  t_yfvh_cards_calc_balances                t_kcog_currency
# 842  t_yfvh_cards_calc_balances   t_ksan_contract_global_local
#
#                                                    job   version
# 0       b0hn-gl-hmm-qlt-aggoutputemshglmrfield-01.json  "17.2.0"
# 1      b0hn-gl-hmm-qlt-aggoutputemshglmrobject-01.json  "17.2.0"
# 2        b0hn-gl-hmm-qlt-aggoutputemshglmmrule-01.json  "17.2.0"
# 3         b0hn-gl-hmm-qlt-sustgroupmarkmrfield-01.json  "17.2.0"
# 4        b0hn-gl-hmm-qlt-sustgroupmarkmrobject-01.json  "17.2.0"
# ..                                                 ...       ...
# 838  yfvh-gl-hmm-qlt-cardscalcbalancesmrobject-01.json  "16.1.5"
# 839    yfvh-gl-hmm-qlt-cardscalcbalancesmmrule-01.json  "16.1.5"
# 840    yfvh-gl-hmm-qlt-cardscalcbalancesmmrule-02.json  "16.1.5"
# 841    yfvh-gl-hmm-qlt-cardscalcbalancesmmrule-03.json  "16.1.5"
# 842    yfvh-gl-hmm-qlt-cardscalcbalancesmmrule-04.json  "16.1.5"
#
# [843 rows x 6 columns]

# %%
version = '"17.3.0"'
print('uuaas:',conf_url[conf_url.version == version].conf.str[:4].unique())
conf_url_version = conf_url[conf_url.version == version]
conf_url_version
# Out:
# uuaas: ['G5M3' 'KSZG' 'P6R1']
#                                                  conf  \
# 4                  G5M3_agg-mlzed-amount_MRField.conf
# 3   G5M3_agg-mlzed-amount_SCAT_sustainability-hier...
# 11        G5M3_movement-carbon-footprint_MRField.conf
# 10       G5M3_movement-carbon-footprint_MRObject.conf
# 13  G5M3_movement-carbon-footprint_KMOL_account-mo...
# 14  G5M3_movement-carbon-footprint_KCOG_entity_MMR...
# 15  G5M3_movement-carbon-footprint_KCOG_country_MM...
# 6               G5M3_sust-mob-operations_MRField.conf
# 25             G5M3_sust-mob-operations_MRObject.conf
# 26  G5M3_sust-mob-operations_KSAN_contract-global-...
# 5           G5M3_sust-mob-operations-cib_MRField.conf
# 24         G5M3_sust-mob-operations-cib_MRObject.conf
# 0   G5M3_sust-mob-operations-cib_G5M3_sust-mob-ope...
# 33  G5M3_sust-mob-operations-cib_KCOG_entity_MMRul...
# 7           G5M3_sust-mob-operations-eod_MRField.conf
# 29         G5M3_sust-mob-operations-eod_MRObject.conf
# 28  G5M3_sust-mob-operations-eod_KSAN_contract-glo...
# 9                  KSZG_queue-controller_MRField.conf
# 8                 KSZG_queue-controller_MRObject.conf
# 20      KSZG_queue-controller_KCOG_branch_MMRule.conf
# 21      KSZG_queue-controller_KCOG_entity_MMRule.conf
# 22     KSZG_queue-controller_KCOG_country_MMRule.conf
# 27  KSZG_queue-controller_KBTQ_role-person_MMRule....
# 1                KSZG_trnslty-by-channel_MRField.conf
# 12              KSZG_trnslty-by-channel_MRObject.conf
# 16  KSZG_trnslty-by-channel_KCOG_currency_MMRule.conf
# 17    KSZG_trnslty-by-channel_KCOG_branch_MMRule.conf
# 18    KSZG_trnslty-by-channel_KCOG_entity_MMRule.conf
# 19   KSZG_trnslty-by-channel_KCOG_country_MMRule.conf
# 23  KSZG_trnslty-by-channel_KSAN_contract-global-l...
# 31        P6R1_customer-socio-demo-board_MRField.conf
# 30           P6R1_interaction-by-channel_MRField.conf
# 32                   P6R1_movements-hist_MRField.conf
# 2           P6R1_prt-cont-prdt-bal-board_MRField.conf
#
#                                               job_url  \
# 4   https://bitbucket.globaldevtools.bbva.com/bitb...
# 3   https://bitbucket.globaldevtools.bbva.com/bitb...
# 11  https://bitbucket.globaldevtools.bbva.com/bitb...
# 10  https://bitbucket.globaldevtools.bbva.com/bitb...
# 13  https://bitbucket.globaldevtools.bbva.com/bitb...
# 14  https://bitbucket.globaldevtools.bbva.com/bitb...
# 15  https://bitbucket.globaldevtools.bbva.com/bitb...
# 6   https://bitbucket.globaldevtools.bbva.com/bitb...
# 25  https://bitbucket.globaldevtools.bbva.com/bitb...
# 26  https://bitbucket.globaldevtools.bbva.com/bitb...
# 5   https://bitbucket.globaldevtools.bbva.com/bitb...
# 24  https://bitbucket.globaldevtools.bbva.com/bitb...
# 0   https://bitbucket.globaldevtools.bbva.com/bitb...
# 33  https://bitbucket.globaldevtools.bbva.com/bitb...
# 7   https://bitbucket.globaldevtools.bbva.com/bitb...
# 29  https://bitbucket.globaldevtools.bbva.com/bitb...
# 28  https://bitbucket.globaldevtools.bbva.com/bitb...
# 9   https://bitbucket.globaldevtools.bbva.com/bitb...
# 8   https://bitbucket.globaldevtools.bbva.com/bitb...
# 20  https://bitbucket.globaldevtools.bbva.com/bitb...
# 21  https://bitbucket.globaldevtools.bbva.com/bitb...
# 22  https://bitbucket.globaldevtools.bbva.com/bitb...
# 27  https://bitbucket.globaldevtools.bbva.com/bitb...
# 1   https://bitbucket.globaldevtools.bbva.com/bitb...
# 12  https://bitbucket.globaldevtools.bbva.com/bitb...
# 16  https://bitbucket.globaldevtools.bbva.com/bitb...
# 17  https://bitbucket.globaldevtools.bbva.com/bitb...
# 18  https://bitbucket.globaldevtools.bbva.com/bitb...
# 19  https://bitbucket.globaldevtools.bbva.com/bitb...
# 23  https://bitbucket.globaldevtools.bbva.com/bitb...
# 31  https://bitbucket.globaldevtools.bbva.com/bitb...
# 30  https://bitbucket.globaldevtools.bbva.com/bitb...
# 32  https://bitbucket.globaldevtools.bbva.com/bitb...
# 2   https://bitbucket.globaldevtools.bbva.com/bitb...
#
#                                table                 secundary_table  \
# 4            t_g5m3_agg_mlzed_amount                             NaN
# 3            t_g5m3_agg_mlzed_amount  t_scat_sustainability_hierarch
# 11  t_g5m3_movement_carbon_footprint                             NaN
# 10  t_g5m3_movement_carbon_footprint                             NaN
# 13  t_g5m3_movement_carbon_footprint        t_kmol_account_movements
# 14  t_g5m3_movement_carbon_footprint                   t_kcog_entity
# 15  t_g5m3_movement_carbon_footprint                  t_kcog_country
# 6         t_g5m3_sust_mob_operations                             NaN
# 25        t_g5m3_sust_mob_operations                             NaN
# 26        t_g5m3_sust_mob_operations    t_ksan_contract_global_local
# 5     t_g5m3_sust_mob_operations_cib                             NaN
# 24    t_g5m3_sust_mob_operations_cib                             NaN
# 0     t_g5m3_sust_mob_operations_cib  t_g5m3_sust_mob_operations_cib
# 33    t_g5m3_sust_mob_operations_cib                   t_kcog_entity
# 7     t_g5m3_sust_mob_operations_eod                             NaN
# 29    t_g5m3_sust_mob_operations_eod                             NaN
# 28    t_g5m3_sust_mob_operations_eod    t_ksan_contract_global_local
# 9            t_kszg_queue_controller                             NaN
# 8            t_kszg_queue_controller                             NaN
# 20           t_kszg_queue_controller                   t_kcog_branch
# 21           t_kszg_queue_controller                   t_kcog_entity
# 22           t_kszg_queue_controller                  t_kcog_country
# 27           t_kszg_queue_controller              t_kbtq_role_person
# 1          t_kszg_trnslty_by_channel                             NaN
# 12         t_kszg_trnslty_by_channel                             NaN
# 16         t_kszg_trnslty_by_channel                 t_kcog_currency
# 17         t_kszg_trnslty_by_channel                   t_kcog_branch
# 18         t_kszg_trnslty_by_channel                   t_kcog_entity
# 19         t_kszg_trnslty_by_channel                  t_kcog_country
# 23         t_kszg_trnslty_by_channel    t_ksan_contract_global_local
# 31  t_p6r1_customer_socio_demo_board                             NaN
# 30     t_p6r1_interaction_by_channel                             NaN
# 32             t_p6r1_movements_hist                             NaN
# 2     t_p6r1_prt_cont_prdt_bal_board                             NaN
#
#                                                   job   version
# 4       g5m3-gl-hmm-qlt-aggmlzedamountmrfield-01.json  "17.3.0"
# 3        g5m3-gl-hmm-qlt-aggmlzedamountmmrule-01.json  "17.3.0"
# 11  g5m3-gl-hmm-qlt-movementcarbonfootpmrfield-01....  "17.3.0"
# 10  g5m3-gl-hmm-qlt-movementcarbonfootpmrobject-01...  "17.3.0"
# 13  g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-01.json  "17.3.0"
# 14  g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-02.json  "17.3.0"
# 15  g5m3-gl-hmm-qlt-movementcarbonfootpmmrule-03.json  "17.3.0"
# 6    g5m3-gl-hmm-qlt-sustmoboperationsmrfield-01.json  "17.3.0"
# 25  g5m3-gl-hmm-qlt-sustmoboperationsmrobject-01.json  "17.3.0"
# 26    g5m3-gl-hmm-qlt-sustmoboperationsmmrule-01.json  "17.3.0"
# 5   g5m3-gl-hmm-qlt-sustmoboperationscimrfield-01....  "17.3.0"
# 24  g5m3-gl-hmm-qlt-sustmoboperationscimrobject-01...  "17.3.0"
# 0   g5m3-gl-hmm-qlt-sustmoboperationscimmrule-01.json  "17.3.0"
# 33  g5m3-gl-hmm-qlt-sustmoboperationscimmrule-02.json  "17.3.0"
# 7   g5m3-gl-hmm-qlt-sustmoboperationseomrfield-01....  "17.3.0"
# 29  g5m3-gl-hmm-qlt-sustmoboperationseomrobject-01...  "17.3.0"
# 28  g5m3-gl-hmm-qlt-sustmoboperationseommrule-01.json  "17.3.0"
# 9      kszg-gl-hmm-qlt-queuecontrollermrfield-01.json  "17.3.0"
# 8     kszg-gl-hmm-qlt-queuecontrollermrobject-01.json  "17.3.0"
# 20      kszg-gl-hmm-qlt-queuecontrollermmrule-01.json  "17.3.0"
# 21      kszg-gl-hmm-qlt-queuecontrollermmrule-02.json  "17.3.0"
# 22      kszg-gl-hmm-qlt-queuecontrollermmrule-03.json  "17.3.0"
# 27      kszg-gl-hmm-qlt-queuecontrollermmrule-04.json  "17.3.0"
# 1     kszg-gl-hmm-qlt-trnsltybychannelmrfield-01.json  "17.3.0"
# 12   kszg-gl-hmm-qlt-trnsltybychannelmrobject-01.json  "17.3.0"
# 16     kszg-gl-hmm-qlt-trnsltybychannelmmrule-01.json  "17.3.0"
# 17     kszg-gl-hmm-qlt-trnsltybychannelmmrule-02.json  "17.3.0"
# 18     kszg-gl-hmm-qlt-trnsltybychannelmmrule-03.json  "17.3.0"
# 19     kszg-gl-hmm-qlt-trnsltybychannelmmrule-04.json  "17.3.0"
# 23     kszg-gl-hmm-qlt-trnsltybychannelmmrule-05.json  "17.3.0"
# 31  p6r1-gl-hmm-qlt-customersociodemobomrfield-01....  "17.3.0"
# 30  p6r1-gl-hmm-qlt-interactionbychannemrfield-01....  "17.3.0"
# 32       p6r1-gl-hmm-qlt-movementshistmrfield-01.json  "17.3.0"
# 2   p6r1-gl-hmm-qlt-prtcontprdtbalboardmrfield-01....  "17.3.0"

# %%
print("versión de subida de jobs:")
print("\n- todos:")
print(list(conf_url.version.sort_values().unique()))
print("\n- por UA:")
list((conf_url.conf.str[:4]+': '+conf_url.version).unique())
# Out:
# versión de subida de jobs:
#
# - todos:
# ['"16.1.5"', '"17.0.0"', '"17.0.1"', '"17.1.0"', '"17.2.0"', '"17.3.0"']
#
# - por UA:
# ['B0HN: "17.2.0"',
#  'CGJ7: "17.2.0"',
#  'CMOV: "17.2.0"',
#  'CTAR: "16.1.5"',
#  'DAST: "16.1.5"',
#  'DTAU: "16.1.5"',
#  'EJB6: "17.0.0"',
#  'FZPD: "17.0.0"',
#  'G5M3: "17.3.0"',
#  'J7IL: "16.1.5"',
#  'KATC: "16.1.5"',
#  'KCDG: "16.1.5"',
#  'KCEG: "17.2.0"',
#  'KCPG: "16.1.5"',
#  'KCTD: "17.0.0"',
#  'KFCM: "17.2.0"',
#  'KMIG: "16.1.5"',
#  'KNFA: "17.1.0"',
#  'KPAN: "17.0.1"',
#  'KSRR: "16.1.5"',
#  'KSTB: "16.1.5"',
#  'KSZG: "17.3.0"',
#  'KUSU: "16.1.5"',
#  'KWTH: "17.2.0"',
#  'L9CT: "17.2.0"',
#  'L9SV: "17.2.0"',
#  'MSX9: "16.1.5"',
#  'NM7R: "16.1.5"',
#  'NOLS: "16.1.5"',
#  'P68X: "16.1.5"',
#  'P6R1: "17.3.0"',
#  'R4FU: "16.1.5"',
#  'RE4M: "17.0.0"',
#  'RZUA: "17.1.0"',
#  'SCAT: "16.1.5"',
#  'TDI3: "16.1.5"',
#  'TLHR: "16.1.5"',
#  'YFVH: "16.1.5"']
